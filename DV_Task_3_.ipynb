# %% [markdown]
# <a href="https://colab.research.google.com/github/veltech-soc/DV_Tasks/blob/main/DV_Task_3_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import seaborn as sns
df = sns.load_dataset('titanic')
display(df.head())
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
df.info()

continuous_cols = ['age', 'sibsp', 'parch', 'fare']
categorical_cols = ['survived', 'pclass', 'sex', 'embarked', 'class', 'who', 'adult_male', 'deck', 'embark_town', 'alive', 'alone']

print("Continuous columns:", continuous_cols)
print("Categorical columns:", categorical_cols)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   survived     891 non-null    int64
#  1   pclass       891 non-null    int64
#  2   sex          891 non-null    object
#  3   age          714 non-null    float64
#  4   sibsp        891 non-null    int64
#  5   parch        891 non-null    int64
#  6   fare         891 non-null    float64
#  7   embarked     889 non-null    object
#  8   class        891 non-null    category
#  9   who          891 non-null    object
#  10  adult_male   891 non-null    bool
#  11  deck         203 non-null    category
#  12  embark_town  889 non-null    object
#  13  alive        891 non-null    object
#  14  alone        891 non-null    bool
# dtypes: bool(2), category(2), float64(2), int64(4), object(5)
# memory usage: 80.7+ KB
# Continuous columns: ['age', 'sibsp', 'parch', 'fare']
# ...

# %%
import matplotlib.pyplot as plt

sns.scatterplot(data=df, x='age', y='fare')
plt.show()

sns.jointplot(data=df, x='age', y='fare', kind='scatter')
plt.show()

# %%
import matplotlib.pyplot as plt

sns.countplot(data=df, x='pclass')
plt.show()

sns.countplot(data=df, x='sex')
plt.show()

sns.countplot(data=df, x='embarked')
plt.show()

# Heatmap of counts of passengers by pclass and survived
survival_counts = pd.crosstab( df['pclass'], df['survived'])
sns.heatmap(survival_counts, annot=True, fmt='d', cmap='Blues')
plt.show()

# Stacked bar plot of counts of passengers by pclass and survived
survival_counts.plot(kind='bar', stacked=True)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-748905868.py in <cell line: 0>()
#      11
#      12 # Heatmap of counts of passengers by pclass and survived
# ---> 13 survival_counts = pd.crosstab( df['pclass'], df['survived'])
#      14 sns.heatmap(survival_counts, annot=True, fmt='d', cmap='Blues')
#      15 plt.show()
#
# NameError: name 'pd' is not defined

# %%
sns.boxplot(data=df, x='pclass', y='age')
plt.show()

sns.violinplot(data=df, x='sex', y='fare')
plt.show()

sns.swarmplot(data=df, x='survived', y='age')
plt.show()
# Out:
# /usr/local/lib/python3.12/dist-packages/seaborn/categorical.py:3399: UserWarning: 5.4% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %%
import matplotlib.pyplot as plt
import seaborn as sns

sns.boxplot(data=df, x='pclass', y='age')
plt.show()

# %%
sns.violinplot(data=df, x='sex', y='fare')
plt.show()

# %%
sns.swarmplot(data=df, x='survived', y='age')
plt.show()
# Out:
# /usr/local/lib/python3.12/dist-packages/seaborn/categorical.py:3399: UserWarning: 5.4% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
